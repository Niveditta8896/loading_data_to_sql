# %%
import pandas as pd

# %%
data=pd.read_csv("train_u6lujuX_CVtuZ9i.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
applicant_info=data.iloc[:,:8]

# %%
applicant_info
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome
# 0               5849                0.0
# 1               4583             1508.0
# ...

# %%
loan_info=data[['Loan_ID','LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']]

# %%
loan_info.isna().sum()
# Out:
# Loan_ID              0
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_info
# Out:
#       Loan_ID  LoanAmount  Loan_Amount_Term  Credit_History Property_Area  \
# 0    LP001002         NaN             360.0             1.0         Urban
# 1    LP001003       128.0             360.0             1.0         Rural
# 2    LP001005        66.0             360.0             1.0         Urban
# 3    LP001006       120.0             360.0             1.0         Urban
# 4    LP001008       141.0             360.0             1.0         Urban
# ..        ...         ...               ...             ...           ...
# 609  LP002978        71.0             360.0             1.0         Rural
# 610  LP002979        40.0             180.0             1.0         Rural
# 611  LP002983       253.0             360.0             1.0         Urban
# 612  LP002984       187.0             360.0             1.0         Urban
# 613  LP002990       133.0             360.0             0.0     Semiurban
#
#     Loan_Status
# 0             Y
# 1             N
# 2             Y
# ...

# %%
applicant_info.to_csv("applicant_info.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24408\3665874435.py in <module>
# ----> 1 applicant_info.to_csv("applicant_info.csv")
#
# ~\anaconda3\envs\aiml\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ...

# %%
loan_info.to_csv("loan_info.csv")

# %%
applicant_info.to_csv("C:/ProgramData/MySQL/MySQL Server 9.2/Uploads/applicant_info.csv", index=False)

# %%
loan_info.to_csv("C:/ProgramData/MySQL/MySQL Server 9.2/Uploads/loan_info.csv", index=False,na_rep="\\N")
